# %%
import pandas as pd
from IPython.display import HTML

# %%
filepath ="HateCrimeGrouped.csv"
df = pd.read_csv(filepath)

df.head()
# Out:
#    Year          Crime_Type                              Bias_Type  \
# 0  2015  Aggravated Assault  Anti-American Indian or Alaska Native
# 1  2015  Aggravated Assault  Anti-American Indian or Alaska Native
# 2  2015  Aggravated Assault  Anti-American Indian or Alaska Native
# 3  2015  Aggravated Assault                              Anti-Arab
# 4  2015  Aggravated Assault                              Anti-Arab
#
#                       Offender_Race  Count  Victim_Sum
# 0  American Indian or Alaska Native      3           3
# 1         Black or African American      4           4
# 2                           Unknown      1           1
# 3         Black or African American      1           1
# 4                             White      2           2

# %%
result=df.to_html(index=False)
print(result)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Year</th>
#       <th>Crime_Type</th>
#       <th>Bias_Type</th>
#       <th>Offender_Race</th>
#       <th>Count</th>
#       <th>Victim_Sum</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2015</td>
#       <td>Aggravated Assault</td>
#       <td>Anti-American Indian or Alaska Native</td>
#       <td>American Indian or Alaska Native</td>
#       <td>3</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>2015</td>
#       <td>Aggravated Assault</td>
#       <td>Anti-American Indian or Alaska Native</td>
#       <td>Black or African American</td>
#       <td>4</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>2015</td>
#       <td>Aggravated Assault</td>
#       <td>Anti-American Indian or Alaska Native</td>
#       <td>Unknown</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>2015</td>
#       <td>Aggravated Assault</td>
# ...
