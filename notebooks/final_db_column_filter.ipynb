# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# we are going with the last decade 2010 through 2020

filepath2 = "hatecrimes_2010_2020.csv"

# %%
# read in dataset into pandas
df2 = pd.read_csv(filepath2)

df2.info()
# Out:
# C:\Users\jonwukeme\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219073 entries, 0 to 219072
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   INCIDENT_ID               219073 non-null  int64
#  1   DATA_YEAR                 219073 non-null  int64
#  2   ORI                       219073 non-null  object
#  3   PUB_AGENCY_NAME           219073 non-null  object
#  4   PUB_AGENCY_UNIT           6427 non-null    object
#  5   AGENCY_TYPE_NAME          219073 non-null  object
#  6   STATE_ABBR                219073 non-null  object
#  7   STATE_NAME                219073 non-null  object
#  8   DIVISION_NAME             219073 non-null  object
#  9   REGION_NAME               219073 non-null  object
#  10  POPULATION_GROUP_CODE     219073 non-null  object
#  11  POPULATION_GROUP_DESC     219073 non-null  object
#  12  INCIDENT_DATE             219073 non-null  object
#  13  ADULT_VICTIM_COUNT        50907 non-null   float64
#  14  JUVENILE_VICTIM_COUNT     49035 non-null   float64
#  15  TOTAL_OFFENDER_COUNT      219073 non-null  int64
#  16  ADULT_OFFENDER_COUNT      46841 non-null   float64
#  17  JUVENILE_OFFENDER_COUNT   46834 non-null   float64
#  18  OFFENDER_RACE             219053 non-null  object
#  19  OFFENDER_ETHNICITY        34369 non-null   object
#  20  VICTIM_COUNT              219073 non-null  int64
#  21  OFFENSE_NAME              219073 non-null  object
#  22  TOTAL_INDIVIDUAL_VICTIMS  215594 non-null  float64
#  23  LOCATION_NAME             219073 non-null  object
#  24  BIAS_DESC                 219073 non-null  object
#  25  VICTIM_TYPES              219073 non-null  object
#  26  MULTIPLE_OFFENSE          219073 non-null  object
#  27  MULTIPLE_BIAS             219073 non-null  object
# dtypes: float64(5), int64(4), object(19)
# memory usage: 46.8+ MB

# %%
# retrieve the columns in the dataset
df2.columns
# Out:
# Index(['INCIDENT_ID', 'DATA_YEAR', 'ORI', 'PUB_AGENCY_NAME', 'PUB_AGENCY_UNIT',
#        'AGENCY_TYPE_NAME', 'STATE_ABBR', 'STATE_NAME', 'DIVISION_NAME',
#        'REGION_NAME', 'POPULATION_GROUP_CODE', 'POPULATION_GROUP_DESC',
#        'INCIDENT_DATE', 'ADULT_VICTIM_COUNT', 'JUVENILE_VICTIM_COUNT',
#        'TOTAL_OFFENDER_COUNT', 'ADULT_OFFENDER_COUNT',
#        'JUVENILE_OFFENDER_COUNT', 'OFFENDER_RACE', 'OFFENDER_ETHNICITY',
#        'VICTIM_COUNT', 'OFFENSE_NAME', 'TOTAL_INDIVIDUAL_VICTIMS',
#        'LOCATION_NAME', 'BIAS_DESC', 'VICTIM_TYPES', 'MULTIPLE_OFFENSE',
#        'MULTIPLE_BIAS'],
#       dtype='object')

# %%
# create a dataset with the columns selected
cols = ["DATA_YEAR","STATE_ABBR","STATE_NAME","REGION_NAME","POPULATION_GROUP_DESC","INCIDENT_DATE","OFFENDER_RACE","VICTIM_COUNT","OFFENSE_NAME","LOCATION_NAME","BIAS_DESC","VICTIM_TYPES"]
proj_df = df2.loc[:, cols]
proj_df
# Out:
#         DATA_YEAR STATE_ABBR STATE_NAME REGION_NAME  \
# 0            1991         AR   Arkansas       South
# 1            1991         AR   Arkansas       South
# 2            1991         AR   Arkansas       South
# 3            1991         AR   Arkansas       South
# 4            1991         AR   Arkansas       South
# ...           ...        ...        ...         ...
# 219068       2020         WY    Wyoming        West
# 219069       2020         WY    Wyoming        West
# 219070       2020         WY    Wyoming        West
# 219071       2020         WY    Wyoming        West
# 219072       2020         WY    Wyoming        West
#
#                  POPULATION_GROUP_DESC INCIDENT_DATE  \
# 0       Cities from 10,000 thru 24,999     31-AUG-91
# 1         Cities from 2,500 thru 9,999     19-SEP-91
# 2       Cities from 50,000 thru 99,999     04-JUL-91
# 3       Cities from 50,000 thru 99,999     24-DEC-91
# 4       Cities from 50,000 thru 99,999     23-DEC-91
# ...                                ...           ...
# 219068  Cities from 10,000 thru 24,999     29-NOV-20
# 219069  Cities from 10,000 thru 24,999     14-JUL-20
# 219070  Cities from 10,000 thru 24,999     16-OCT-20
# 219071  Cities from 10,000 thru 24,999     30-JAN-20
# 219072  Cities from 10,000 thru 24,999     21-NOV-20
#
#                     OFFENDER_RACE  VICTIM_COUNT  \
# 0                           White             1
# 1       Black or African American             1
# 2       Black or African American             1
# 3       Black or African American             2
# 4       Black or African American             1
# ...                           ...           ...
# 219068                      White             2
# 219069                    Unknown             1
# 219070  Black or African American             1
# 219071                      White             1
# 219072                      White             1
#
#                                              OFFENSE_NAME  \
# 0                                            Intimidation
# 1                                          Simple Assault
# 2                                      Aggravated Assault
# 3       Aggravated Assault;Destruction/Damage/Vandalis...
# 4                                      Aggravated Assault
# ...                                                   ...
# 219068                                       Intimidation
# 219069           Destruction/Damage/Vandalism of Property
# 219070                                 Aggravated Assault
# 219071                                     Simple Assault
# 219072                                Theft From Building
#
#                              LOCATION_NAME  \
# 0       Highway/Road/Alley/Street/Sidewalk
# 1       Highway/Road/Alley/Street/Sidewalk
# 2                           Residence/Home
# 3       Highway/Road/Alley/Street/Sidewalk
# 4                      Service/Gas Station
# ...                                    ...
# 219068                     Park/Playground
# 219069                     Park/Playground
# 219070                      Residence/Home
# 219071                      Residence/Home
# 219072                      Residence/Home
#
#                                                 BIAS_DESC VICTIM_TYPES
# 0                          Anti-Black or African American   Individual
# 1                                              Anti-White   Individual
# 2                          Anti-Black or African American   Individual
# 3                                              Anti-White   Individual
# 4                                              Anti-White   Individual
# ...                                                   ...          ...
# 219068  Anti-Lesbian, Gay, Bisexual, or Transgender (M...   Individual
# 219069                                         Anti-White   Government
# 219070                                         Anti-White   Individual
# 219071                                        Anti-Female   Individual
# 219072                         Anti-Gender Non-Conforming   Individual
#
# [219073 rows x 12 columns]

# %%
# filter for DATA_YEAR greater than 2010
mask = (proj_df["DATA_YEAR"] >= 2010)
projyr_df = proj_df.loc[mask, :]
projyr_df
# Out:
#         DATA_YEAR STATE_ABBR STATE_NAME REGION_NAME  \
# 143578       2010         AK     Alaska        West
# 143579       2010         AK     Alaska        West
# 143580       2010         AK     Alaska        West
# 143581       2010         AK     Alaska        West
# 143582       2010         AK     Alaska        West
# ...           ...        ...        ...         ...
# 219068       2020         WY    Wyoming        West
# 219069       2020         WY    Wyoming        West
# 219070       2020         WY    Wyoming        West
# 219071       2020         WY    Wyoming        West
# 219072       2020         WY    Wyoming        West
#
#                    POPULATION_GROUP_DESC INCIDENT_DATE  \
# 143578  Cities from 250,000 thru 499,999     14-JUL-10
# 143579  Cities from 250,000 thru 499,999     14-JUL-10
# 143580  Cities from 250,000 thru 499,999     17-SEP-10
# 143581  Cities from 250,000 thru 499,999     21-SEP-10
# 143582  Cities from 250,000 thru 499,999     01-OCT-10
# ...                                  ...           ...
# 219068    Cities from 10,000 thru 24,999     29-NOV-20
# 219069    Cities from 10,000 thru 24,999     14-JUL-20
# 219070    Cities from 10,000 thru 24,999     16-OCT-20
# 219071    Cities from 10,000 thru 24,999     30-JAN-20
# 219072    Cities from 10,000 thru 24,999     21-NOV-20
#
#                            OFFENDER_RACE  VICTIM_COUNT  \
# 143578                             White             2
# 143579         Black or African American             1
# 143580  American Indian or Alaska Native             2
# 143581  American Indian or Alaska Native             1
# 143582                             White             1
# ...                                  ...           ...
# 219068                             White             2
# 219069                           Unknown             1
# 219070         Black or African American             1
# 219071                             White             1
# 219072                             White             1
#
#                                     OFFENSE_NAME  \
# 143578                        Aggravated Assault
# 143579                            Simple Assault
# 143580                            Simple Assault
# 143581                        Aggravated Assault
# 143582                              Intimidation
# ...                                          ...
# 219068                              Intimidation
# 219069  Destruction/Damage/Vandalism of Property
# 219070                        Aggravated Assault
# 219071                            Simple Assault
# 219072                       Theft From Building
#
#                                         LOCATION_NAME  \
# 143578             Highway/Road/Alley/Street/Sidewalk
# 143579  Jail/Prison/Penitentiary/Corrections Facility
# 143580                                   Liquor Store
# 143581                                 Residence/Home
# 143582             Highway/Road/Alley/Street/Sidewalk
# ...                                               ...
# 219068                                Park/Playground
# 219069                                Park/Playground
# 219070                                 Residence/Home
# 219071                                 Residence/Home
# 219072                                 Residence/Home
#
#                                                 BIAS_DESC VICTIM_TYPES
# 143578                     Anti-Black or African American   Individual
# 143579                                    Anti-Gay (Male)   Individual
# 143580                                         Anti-White   Individual
# 143581                                         Anti-White   Individual
# 143582                              Anti-Islamic (Muslim)   Individual
# ...                                                   ...          ...
# 219068  Anti-Lesbian, Gay, Bisexual, or Transgender (M...   Individual
# 219069                                         Anti-White   Government
# 219070                                         Anti-White   Individual
# 219071                                        Anti-Female   Individual
# 219072                         Anti-Gender Non-Conforming   Individual
#
# [75495 rows x 12 columns]

# %%
projyr_df.to_csv("Final_output.csv", index=False, header=True)

# %%
projyr_df["OFFENSE_NAME"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 143578                          Aggravated Assault
# 143579                              Simple Assault
# 143580                              Simple Assault
# 143581                          Aggravated Assault
# 143582                                Intimidation
#                             ...
# 219068                                Intimidation
# 219069    Destruction/Damage/Vandalism of Property
# 219070                          Aggravated Assault
# 219071                              Simple Assault
# 219072                         Theft From Building
# Name: OFFENSE_NAME, Length: 75495, dtype: object>

# %%
projyr_df["OFFENSE_NAME"].nunique()
# Out:
# 265

# %%
# more focused definition of crimes
projyr_df['LOCATION_NAME'].str.split(";").str[0]
# Out:
# 143578               Highway/Road/Alley/Street/Sidewalk
# 143579    Jail/Prison/Penitentiary/Corrections Facility
# 143580                                     Liquor Store
# 143581                                   Residence/Home
# 143582               Highway/Road/Alley/Street/Sidewalk
#                               ...
# 219068                                  Park/Playground
# 219069                                  Park/Playground
# 219070                                   Residence/Home
# 219071                                   Residence/Home
# 219072                                   Residence/Home
# Name: LOCATION_NAME, Length: 75495, dtype: object

# %%
projyr_df['LOCATION_NAME'].str.split(";").str[0].nunique()
# Out:
# 46

# %%
projyr_df['LOCATION_NAME'].str.split(";").str[0]
# Out:
# 143578               Highway/Road/Alley/Street/Sidewalk
# 143579    Jail/Prison/Penitentiary/Corrections Facility
# 143580                                     Liquor Store
# 143581                                   Residence/Home
# 143582               Highway/Road/Alley/Street/Sidewalk
#                               ...
# 219068                                  Park/Playground
# 219069                                  Park/Playground
# 219070                                   Residence/Home
# 219071                                   Residence/Home
# 219072                                   Residence/Home
# Name: LOCATION_NAME, Length: 75495, dtype: object

# %%
projyr_df['LOCATION_NAME'].str.split("/").str[0].nunique()
# Out:
# 53

# %%
projyr_df['LOCATION_NAME'].str.split("/").str[0]
# Out:
# 143578         Highway
# 143579            Jail
# 143580    Liquor Store
# 143581       Residence
# 143582         Highway
#               ...
# 219068            Park
# 219069            Park
# 219070       Residence
# 219071       Residence
# 219072       Residence
# Name: LOCATION_NAME, Length: 75495, dtype: object

# %%
plt.figure(figsize=(12,6))
corrs=projyr_df.corr()

sns.heatmap(corrs)

plt.show()

# %%
projyr_df.columns
# Out:
# Index(['DATA_YEAR', 'STATE_ABBR', 'STATE_NAME', 'REGION_NAME',
#        'POPULATION_GROUP_DESC', 'INCIDENT_DATE', 'OFFENDER_RACE',
#        'VICTIM_COUNT', 'OFFENSE_NAME', 'LOCATION_NAME', 'BIAS_DESC',
#        'VICTIM_TYPES'],
#       dtype='object')

# %%
projyr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75495 entries, 143578 to 219072
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATA_YEAR              75495 non-null  int64
#  1   STATE_ABBR             75495 non-null  object
#  2   STATE_NAME             75495 non-null  object
#  3   REGION_NAME            75495 non-null  object
#  4   POPULATION_GROUP_DESC  75495 non-null  object
#  5   INCIDENT_DATE          75495 non-null  object
#  6   OFFENDER_RACE          75475 non-null  object
#  7   VICTIM_COUNT           75495 non-null  int64
#  8   OFFENSE_NAME           75495 non-null  object
#  9   LOCATION_NAME          75495 non-null  object
#  10  BIAS_DESC              75495 non-null  object
#  11  VICTIM_TYPES           75495 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 7.5+ MB

# %%
projyr_df.head()
# Out:
#         DATA_YEAR STATE_ABBR STATE_NAME REGION_NAME  \
# 143578       2010         AK     Alaska        West
# 143579       2010         AK     Alaska        West
# 143580       2010         AK     Alaska        West
# 143581       2010         AK     Alaska        West
# 143582       2010         AK     Alaska        West
#
#                    POPULATION_GROUP_DESC INCIDENT_DATE  \
# 143578  Cities from 250,000 thru 499,999     14-JUL-10
# 143579  Cities from 250,000 thru 499,999     14-JUL-10
# 143580  Cities from 250,000 thru 499,999     17-SEP-10
# 143581  Cities from 250,000 thru 499,999     21-SEP-10
# 143582  Cities from 250,000 thru 499,999     01-OCT-10
#
#                            OFFENDER_RACE  VICTIM_COUNT        OFFENSE_NAME  \
# 143578                             White             2  Aggravated Assault
# 143579         Black or African American             1      Simple Assault
# 143580  American Indian or Alaska Native             2      Simple Assault
# 143581  American Indian or Alaska Native             1  Aggravated Assault
# 143582                             White             1        Intimidation
#
#                                         LOCATION_NAME  \
# 143578             Highway/Road/Alley/Street/Sidewalk
# 143579  Jail/Prison/Penitentiary/Corrections Facility
# 143580                                   Liquor Store
# 143581                                 Residence/Home
# 143582             Highway/Road/Alley/Street/Sidewalk
#
#                              BIAS_DESC VICTIM_TYPES
# 143578  Anti-Black or African American   Individual
# 143579                 Anti-Gay (Male)   Individual
# 143580                      Anti-White   Individual
# 143581                      Anti-White   Individual
# 143582           Anti-Islamic (Muslim)   Individual

# %%
projyr_df['LOCATION_NAME_1(/)'] = projyr_df['LOCATION_NAME'].str.split("/").str[0]
# Out:
# C:\Users\JONWUK~1\AppData\Local\Temp/ipykernel_25068/710853610.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   projyr_df['LOCATION_NAME_1(/)'] = projyr_df['LOCATION_NAME'].str.split("/").str[0]

# %%
projyr_df
# Out:
#         DATA_YEAR STATE_ABBR STATE_NAME REGION_NAME  \
# 143578       2010         AK     Alaska        West
# 143579       2010         AK     Alaska        West
# 143580       2010         AK     Alaska        West
# 143581       2010         AK     Alaska        West
# 143582       2010         AK     Alaska        West
# ...           ...        ...        ...         ...
# 219068       2020         WY    Wyoming        West
# 219069       2020         WY    Wyoming        West
# 219070       2020         WY    Wyoming        West
# 219071       2020         WY    Wyoming        West
# 219072       2020         WY    Wyoming        West
#
#                    POPULATION_GROUP_DESC INCIDENT_DATE  \
# 143578  Cities from 250,000 thru 499,999     14-JUL-10
# 143579  Cities from 250,000 thru 499,999     14-JUL-10
# 143580  Cities from 250,000 thru 499,999     17-SEP-10
# 143581  Cities from 250,000 thru 499,999     21-SEP-10
# 143582  Cities from 250,000 thru 499,999     01-OCT-10
# ...                                  ...           ...
# 219068    Cities from 10,000 thru 24,999     29-NOV-20
# 219069    Cities from 10,000 thru 24,999     14-JUL-20
# 219070    Cities from 10,000 thru 24,999     16-OCT-20
# 219071    Cities from 10,000 thru 24,999     30-JAN-20
# 219072    Cities from 10,000 thru 24,999     21-NOV-20
#
#                            OFFENDER_RACE  VICTIM_COUNT  \
# 143578                             White             2
# 143579         Black or African American             1
# 143580  American Indian or Alaska Native             2
# 143581  American Indian or Alaska Native             1
# 143582                             White             1
# ...                                  ...           ...
# 219068                             White             2
# 219069                           Unknown             1
# 219070         Black or African American             1
# 219071                             White             1
# 219072                             White             1
#
#                                     OFFENSE_NAME  \
# 143578                        Aggravated Assault
# 143579                            Simple Assault
# 143580                            Simple Assault
# 143581                        Aggravated Assault
# 143582                              Intimidation
# ...                                          ...
# 219068                              Intimidation
# 219069  Destruction/Damage/Vandalism of Property
# 219070                        Aggravated Assault
# 219071                            Simple Assault
# 219072                       Theft From Building
#
#                                         LOCATION_NAME  \
# 143578             Highway/Road/Alley/Street/Sidewalk
# 143579  Jail/Prison/Penitentiary/Corrections Facility
# 143580                                   Liquor Store
# 143581                                 Residence/Home
# 143582             Highway/Road/Alley/Street/Sidewalk
# ...                                               ...
# 219068                                Park/Playground
# 219069                                Park/Playground
# 219070                                 Residence/Home
# 219071                                 Residence/Home
# 219072                                 Residence/Home
#
#                                                 BIAS_DESC VICTIM_TYPES  \
# 143578                     Anti-Black or African American   Individual
# 143579                                    Anti-Gay (Male)   Individual
# 143580                                         Anti-White   Individual
# 143581                                         Anti-White   Individual
# 143582                              Anti-Islamic (Muslim)   Individual
# ...                                                   ...          ...
# 219068  Anti-Lesbian, Gay, Bisexual, or Transgender (M...   Individual
# 219069                                         Anti-White   Government
# 219070                                         Anti-White   Individual
# 219071                                        Anti-Female   Individual
# 219072                         Anti-Gender Non-Conforming   Individual
#
#        LOCATION_NAME_1                                LOCATION_NAME_2  \
# 143578         Highway             Highway/Road/Alley/Street/Sidewalk
# 143579            Jail  Jail/Prison/Penitentiary/Corrections Facility
# 143580    Liquor Store                                   Liquor Store
# 143581       Residence                                 Residence/Home
# 143582         Highway             Highway/Road/Alley/Street/Sidewalk
# ...                ...                                            ...
# 219068            Park                                Park/Playground
# 219069            Park                                Park/Playground
# 219070       Residence                                 Residence/Home
# 219071       Residence                                 Residence/Home
# 219072       Residence                                 Residence/Home
#
#        LOCATION_NAME_1(/)
# 143578            Highway
# 143579               Jail
# 143580       Liquor Store
# 143581          Residence
# 143582            Highway
# ...                   ...
# 219068               Park
# 219069               Park
# 219070          Residence
# 219071          Residence
# 219072          Residence
#
# [75495 rows x 15 columns]

# %%
projyr_df['LOCATION_NAME_2(;)'] = projyr_df['LOCATION_NAME'].str.split(";").str[0]
# Out:
# C:\Users\JONWUK~1\AppData\Local\Temp/ipykernel_25068/1169815715.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   projyr_df['LOCATION_NAME_2(;)'] = projyr_df['LOCATION_NAME'].str.split(";").str[0]

# %%
projyr_df
# Out:
#         DATA_YEAR STATE_ABBR STATE_NAME REGION_NAME  \
# 143578       2010         AK     Alaska        West
# 143579       2010         AK     Alaska        West
# 143580       2010         AK     Alaska        West
# 143581       2010         AK     Alaska        West
# 143582       2010         AK     Alaska        West
# ...           ...        ...        ...         ...
# 219068       2020         WY    Wyoming        West
# 219069       2020         WY    Wyoming        West
# 219070       2020         WY    Wyoming        West
# 219071       2020         WY    Wyoming        West
# 219072       2020         WY    Wyoming        West
#
#                    POPULATION_GROUP_DESC INCIDENT_DATE  \
# 143578  Cities from 250,000 thru 499,999     14-JUL-10
# 143579  Cities from 250,000 thru 499,999     14-JUL-10
# 143580  Cities from 250,000 thru 499,999     17-SEP-10
# 143581  Cities from 250,000 thru 499,999     21-SEP-10
# 143582  Cities from 250,000 thru 499,999     01-OCT-10
# ...                                  ...           ...
# 219068    Cities from 10,000 thru 24,999     29-NOV-20
# 219069    Cities from 10,000 thru 24,999     14-JUL-20
# 219070    Cities from 10,000 thru 24,999     16-OCT-20
# 219071    Cities from 10,000 thru 24,999     30-JAN-20
# 219072    Cities from 10,000 thru 24,999     21-NOV-20
#
#                            OFFENDER_RACE  VICTIM_COUNT  \
# 143578                             White             2
# 143579         Black or African American             1
# 143580  American Indian or Alaska Native             2
# 143581  American Indian or Alaska Native             1
# 143582                             White             1
# ...                                  ...           ...
# 219068                             White             2
# 219069                           Unknown             1
# 219070         Black or African American             1
# 219071                             White             1
# 219072                             White             1
#
#                                     OFFENSE_NAME  \
# 143578                        Aggravated Assault
# 143579                            Simple Assault
# 143580                            Simple Assault
# 143581                        Aggravated Assault
# 143582                              Intimidation
# ...                                          ...
# 219068                              Intimidation
# 219069  Destruction/Damage/Vandalism of Property
# 219070                        Aggravated Assault
# 219071                            Simple Assault
# 219072                       Theft From Building
#
#                                         LOCATION_NAME  \
# 143578             Highway/Road/Alley/Street/Sidewalk
# 143579  Jail/Prison/Penitentiary/Corrections Facility
# 143580                                   Liquor Store
# 143581                                 Residence/Home
# 143582             Highway/Road/Alley/Street/Sidewalk
# ...                                               ...
# 219068                                Park/Playground
# 219069                                Park/Playground
# 219070                                 Residence/Home
# 219071                                 Residence/Home
# 219072                                 Residence/Home
#
#                                                 BIAS_DESC VICTIM_TYPES  \
# 143578                     Anti-Black or African American   Individual
# 143579                                    Anti-Gay (Male)   Individual
# 143580                                         Anti-White   Individual
# 143581                                         Anti-White   Individual
# 143582                              Anti-Islamic (Muslim)   Individual
# ...                                                   ...          ...
# 219068  Anti-Lesbian, Gay, Bisexual, or Transgender (M...   Individual
# 219069                                         Anti-White   Government
# 219070                                         Anti-White   Individual
# 219071                                        Anti-Female   Individual
# 219072                         Anti-Gender Non-Conforming   Individual
#
#        LOCATION_NAME_1                                LOCATION_NAME_2  \
# 143578         Highway             Highway/Road/Alley/Street/Sidewalk
# 143579            Jail  Jail/Prison/Penitentiary/Corrections Facility
# 143580    Liquor Store                                   Liquor Store
# 143581       Residence                                 Residence/Home
# 143582         Highway             Highway/Road/Alley/Street/Sidewalk
# ...                ...                                            ...
# 219068            Park                                Park/Playground
# 219069            Park                                Park/Playground
# 219070       Residence                                 Residence/Home
# 219071       Residence                                 Residence/Home
# 219072       Residence                                 Residence/Home
#
#        LOCATION_NAME_1(/)                             LOCATION_NAME_2(;)
# 143578            Highway             Highway/Road/Alley/Street/Sidewalk
# 143579               Jail  Jail/Prison/Penitentiary/Corrections Facility
# 143580       Liquor Store                                   Liquor Store
# 143581          Residence                                 Residence/Home
# 143582            Highway             Highway/Road/Alley/Street/Sidewalk
# ...                   ...                                            ...
# 219068               Park                                Park/Playground
# 219069               Park                                Park/Playground
# 219070          Residence                                 Residence/Home
# 219071          Residence                                 Residence/Home
# 219072          Residence                                 Residence/Home
#
# [75495 rows x 16 columns]

# %%
projyr_df.columns
# Out:
# Index(['DATA_YEAR', 'STATE_ABBR', 'STATE_NAME', 'REGION_NAME',
#        'POPULATION_GROUP_DESC', 'INCIDENT_DATE', 'OFFENDER_RACE',
#        'VICTIM_COUNT', 'OFFENSE_NAME', 'LOCATION_NAME', 'BIAS_DESC',
#        'VICTIM_TYPES', 'LOCATION_NAME_1', 'LOCATION_NAME_2',
#        'LOCATION_NAME_1(/)', 'LOCATION_NAME_2(;)'],
#       dtype='object')

# %%
cols2 = ['DATA_YEAR', 'STATE_ABBR', 'STATE_NAME', 'REGION_NAME','POPULATION_GROUP_DESC', 'INCIDENT_DATE', 'OFFENDER_RACE','VICTIM_COUNT', 'OFFENSE_NAME', 'LOCATION_NAME','LOCATION_NAME_1(/)', 'LOCATION_NAME_2(;)','BIAS_DESC','VICTIM_TYPES']
projyr2_df = projyr_df.loc[:, cols2]
projyr2_df
# Out:
#         DATA_YEAR STATE_ABBR STATE_NAME REGION_NAME  \
# 143578       2010         AK     Alaska        West
# 143579       2010         AK     Alaska        West
# 143580       2010         AK     Alaska        West
# 143581       2010         AK     Alaska        West
# 143582       2010         AK     Alaska        West
# ...           ...        ...        ...         ...
# 219068       2020         WY    Wyoming        West
# 219069       2020         WY    Wyoming        West
# 219070       2020         WY    Wyoming        West
# 219071       2020         WY    Wyoming        West
# 219072       2020         WY    Wyoming        West
#
#                    POPULATION_GROUP_DESC INCIDENT_DATE  \
# 143578  Cities from 250,000 thru 499,999     14-JUL-10
# 143579  Cities from 250,000 thru 499,999     14-JUL-10
# 143580  Cities from 250,000 thru 499,999     17-SEP-10
# 143581  Cities from 250,000 thru 499,999     21-SEP-10
# 143582  Cities from 250,000 thru 499,999     01-OCT-10
# ...                                  ...           ...
# 219068    Cities from 10,000 thru 24,999     29-NOV-20
# 219069    Cities from 10,000 thru 24,999     14-JUL-20
# 219070    Cities from 10,000 thru 24,999     16-OCT-20
# 219071    Cities from 10,000 thru 24,999     30-JAN-20
# 219072    Cities from 10,000 thru 24,999     21-NOV-20
#
#                            OFFENDER_RACE  VICTIM_COUNT  \
# 143578                             White             2
# 143579         Black or African American             1
# 143580  American Indian or Alaska Native             2
# 143581  American Indian or Alaska Native             1
# 143582                             White             1
# ...                                  ...           ...
# 219068                             White             2
# 219069                           Unknown             1
# 219070         Black or African American             1
# 219071                             White             1
# 219072                             White             1
#
#                                     OFFENSE_NAME  \
# 143578                        Aggravated Assault
# 143579                            Simple Assault
# 143580                            Simple Assault
# 143581                        Aggravated Assault
# 143582                              Intimidation
# ...                                          ...
# 219068                              Intimidation
# 219069  Destruction/Damage/Vandalism of Property
# 219070                        Aggravated Assault
# 219071                            Simple Assault
# 219072                       Theft From Building
#
#                                         LOCATION_NAME LOCATION_NAME_1(/)  \
# 143578             Highway/Road/Alley/Street/Sidewalk            Highway
# 143579  Jail/Prison/Penitentiary/Corrections Facility               Jail
# 143580                                   Liquor Store       Liquor Store
# 143581                                 Residence/Home          Residence
# 143582             Highway/Road/Alley/Street/Sidewalk            Highway
# ...                                               ...                ...
# 219068                                Park/Playground               Park
# 219069                                Park/Playground               Park
# 219070                                 Residence/Home          Residence
# 219071                                 Residence/Home          Residence
# 219072                                 Residence/Home          Residence
#
#                                    LOCATION_NAME_2(;)  \
# 143578             Highway/Road/Alley/Street/Sidewalk
# 143579  Jail/Prison/Penitentiary/Corrections Facility
# 143580                                   Liquor Store
# 143581                                 Residence/Home
# 143582             Highway/Road/Alley/Street/Sidewalk
# ...                                               ...
# 219068                                Park/Playground
# 219069                                Park/Playground
# 219070                                 Residence/Home
# 219071                                 Residence/Home
# 219072                                 Residence/Home
#
#                                                 BIAS_DESC VICTIM_TYPES
# 143578                     Anti-Black or African American   Individual
# 143579                                    Anti-Gay (Male)   Individual
# 143580                                         Anti-White   Individual
# 143581                                         Anti-White   Individual
# 143582                              Anti-Islamic (Muslim)   Individual
# ...                                                   ...          ...
# 219068  Anti-Lesbian, Gay, Bisexual, or Transgender (M...   Individual
# 219069                                         Anti-White   Government
# 219070                                         Anti-White   Individual
# 219071                                        Anti-Female   Individual
# 219072                         Anti-Gender Non-Conforming   Individual
#
# [75495 rows x 14 columns]

# %%
projyr2_df['OFFENSE_NAME_1(/)'] = projyr2_df['OFFENSE_NAME'].str.split("/").str[0]

# %%
projyr2_df['BIAS_DESC_1(/)'] = projyr2_df['BIAS_DESC'].str.split("/").str[0]

# %%
projyr2_df
# Out:
#         DATA_YEAR STATE_ABBR STATE_NAME REGION_NAME  \
# 143578       2010         AK     Alaska        West
# 143579       2010         AK     Alaska        West
# 143580       2010         AK     Alaska        West
# 143581       2010         AK     Alaska        West
# 143582       2010         AK     Alaska        West
# ...           ...        ...        ...         ...
# 219068       2020         WY    Wyoming        West
# 219069       2020         WY    Wyoming        West
# 219070       2020         WY    Wyoming        West
# 219071       2020         WY    Wyoming        West
# 219072       2020         WY    Wyoming        West
#
#                    POPULATION_GROUP_DESC INCIDENT_DATE  \
# 143578  Cities from 250,000 thru 499,999     14-JUL-10
# 143579  Cities from 250,000 thru 499,999     14-JUL-10
# 143580  Cities from 250,000 thru 499,999     17-SEP-10
# 143581  Cities from 250,000 thru 499,999     21-SEP-10
# 143582  Cities from 250,000 thru 499,999     01-OCT-10
# ...                                  ...           ...
# 219068    Cities from 10,000 thru 24,999     29-NOV-20
# 219069    Cities from 10,000 thru 24,999     14-JUL-20
# 219070    Cities from 10,000 thru 24,999     16-OCT-20
# 219071    Cities from 10,000 thru 24,999     30-JAN-20
# 219072    Cities from 10,000 thru 24,999     21-NOV-20
#
#                            OFFENDER_RACE  VICTIM_COUNT  \
# 143578                             White             2
# 143579         Black or African American             1
# 143580  American Indian or Alaska Native             2
# 143581  American Indian or Alaska Native             1
# 143582                             White             1
# ...                                  ...           ...
# 219068                             White             2
# 219069                           Unknown             1
# 219070         Black or African American             1
# 219071                             White             1
# 219072                             White             1
#
#                                     OFFENSE_NAME  \
# 143578                        Aggravated Assault
# 143579                            Simple Assault
# 143580                            Simple Assault
# 143581                        Aggravated Assault
# 143582                              Intimidation
# ...                                          ...
# 219068                              Intimidation
# 219069  Destruction/Damage/Vandalism of Property
# 219070                        Aggravated Assault
# 219071                            Simple Assault
# 219072                       Theft From Building
#
#                                         LOCATION_NAME LOCATION_NAME_1(/)  \
# 143578             Highway/Road/Alley/Street/Sidewalk            Highway
# 143579  Jail/Prison/Penitentiary/Corrections Facility               Jail
# 143580                                   Liquor Store       Liquor Store
# 143581                                 Residence/Home          Residence
# 143582             Highway/Road/Alley/Street/Sidewalk            Highway
# ...                                               ...                ...
# 219068                                Park/Playground               Park
# 219069                                Park/Playground               Park
# 219070                                 Residence/Home          Residence
# 219071                                 Residence/Home          Residence
# 219072                                 Residence/Home          Residence
#
#                                    LOCATION_NAME_2(;)  \
# 143578             Highway/Road/Alley/Street/Sidewalk
# 143579  Jail/Prison/Penitentiary/Corrections Facility
# 143580                                   Liquor Store
# 143581                                 Residence/Home
# 143582             Highway/Road/Alley/Street/Sidewalk
# ...                                               ...
# 219068                                Park/Playground
# 219069                                Park/Playground
# 219070                                 Residence/Home
# 219071                                 Residence/Home
# 219072                                 Residence/Home
#
#                                                 BIAS_DESC VICTIM_TYPES  \
# 143578                     Anti-Black or African American   Individual
# 143579                                    Anti-Gay (Male)   Individual
# 143580                                         Anti-White   Individual
# 143581                                         Anti-White   Individual
# 143582                              Anti-Islamic (Muslim)   Individual
# ...                                                   ...          ...
# 219068  Anti-Lesbian, Gay, Bisexual, or Transgender (M...   Individual
# 219069                                         Anti-White   Government
# 219070                                         Anti-White   Individual
# 219071                                        Anti-Female   Individual
# 219072                         Anti-Gender Non-Conforming   Individual
#
#           OFFENSE_NAME_1(/)                                     BIAS_DESC_1(/)
# 143578   Aggravated Assault                     Anti-Black or African American
# 143579       Simple Assault                                    Anti-Gay (Male)
# 143580       Simple Assault                                         Anti-White
# 143581   Aggravated Assault                                         Anti-White
# 143582         Intimidation                              Anti-Islamic (Muslim)
# ...                     ...                                                ...
# 219068         Intimidation  Anti-Lesbian, Gay, Bisexual, or Transgender (M...
# 219069          Destruction                                         Anti-White
# 219070   Aggravated Assault                                         Anti-White
# 219071       Simple Assault                                        Anti-Female
# 219072  Theft From Building                         Anti-Gender Non-Conforming
#
# [75495 rows x 16 columns]

# %%
projyr2_df.columns
# Out:
# Index(['DATA_YEAR', 'STATE_ABBR', 'STATE_NAME', 'REGION_NAME',
#        'POPULATION_GROUP_DESC', 'INCIDENT_DATE', 'OFFENDER_RACE',
#        'VICTIM_COUNT', 'OFFENSE_NAME', 'LOCATION_NAME', 'LOCATION_NAME_1(/)',
#        'LOCATION_NAME_2(;)', 'BIAS_DESC', 'VICTIM_TYPES', 'OFFENSE_NAME_1(/)',
#        'BIAS_DESC_1(/)'],
#       dtype='object')

# %%
cols2 = ['DATA_YEAR', "INCIDENT_ID", 'STATE_ABBR', 'STATE_NAME', 'REGION_NAME','POPULATION_GROUP_DESC', 'INCIDENT_DATE', 'OFFENDER_RACE','VICTIM_COUNT', 'OFFENSE_NAME', 'OFFENSE_NAME_1(/)', 'LOCATION_NAME','LOCATION_NAME_1(/)', 'LOCATION_NAME_2(;)','BIAS_DESC','BIAS_DESC_1(/)','VICTIM_TYPES']
projyr2_df = projyr_df.loc[:, cols2]
projyr2_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\JONWUK~1\AppData\Local\Temp/ipykernel_25068/1300069301.py in <module>
#       1 cols2 = ['DATA_YEAR', "INCIDENT_ID", 'STATE_ABBR', 'STATE_NAME', 'REGION_NAME','POPULATION_GROUP_DESC', 'INCIDENT_DATE', 'OFFENDER_RACE','VICTIM_COUNT', 'OFFENSE_NAME', 'OFFENSE_NAME_1(/)', 'LOCATION_NAME','LOCATION_NAME_1(/)', 'LOCATION_NAME_2(;)','BIAS_DESC','BIAS_DESC_1(/)','VICTIM_TYPES']
# ----> 2 projyr2_df = projyr_df.loc[:, cols2]
#       3 projyr2_df
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
#    1110
#    1111     def _get_label(self, label, axis: int):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple_same_dim(self, tup)
#     804                 continue
#     805
# --> 806             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     807             # We should never have retval.ndim < self.ndim, as that should
#     808             #  be handled by the _getitem_lowerdim call above.
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1151                     raise ValueError("Cannot index with multidimensional key")
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#    1155             # nested tuple slicing
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1091
#    1092         # A collection of keys
# -> 1093         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1094         return self.obj._reindex_with_indexers(
#    1095             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: "['INCIDENT_ID'] not in index"

# %%
projyr2_df.to_csv("Final_output2.csv", index=False, header=True)

# %%
projyr2_df['BIAS_DESC_1(;)'] = projyr2_df['BIAS_DESC'].str.split(";").str[0]

# %%
projyr2_df['OFFENSE_NAME_1(;)'] = projyr2_df['OFFENSE_NAME'].str.split(";").str[0]

# %%
cols2 = ['DATA_YEAR', 'STATE_ABBR', 'STATE_NAME', 'REGION_NAME','POPULATION_GROUP_DESC', 'INCIDENT_DATE', 'OFFENDER_RACE','VICTIM_COUNT', 'OFFENSE_NAME', 'OFFENSE_NAME_1(;)','LOCATION_NAME','LOCATION_NAME_1(/)','LOCATION_NAME_2(;)','BIAS_DESC','BIAS_DESC_1(;)','VICTIM_TYPES']
projyr2_df = projyr2_df.loc[:, cols2]
projyr2_df
# Out:
#         DATA_YEAR STATE_ABBR STATE_NAME REGION_NAME  \
# 143578       2010         AK     Alaska        West
# 143579       2010         AK     Alaska        West
# 143580       2010         AK     Alaska        West
# 143581       2010         AK     Alaska        West
# 143582       2010         AK     Alaska        West
# ...           ...        ...        ...         ...
# 219068       2020         WY    Wyoming        West
# 219069       2020         WY    Wyoming        West
# 219070       2020         WY    Wyoming        West
# 219071       2020         WY    Wyoming        West
# 219072       2020         WY    Wyoming        West
#
#                    POPULATION_GROUP_DESC INCIDENT_DATE  \
# 143578  Cities from 250,000 thru 499,999     14-JUL-10
# 143579  Cities from 250,000 thru 499,999     14-JUL-10
# 143580  Cities from 250,000 thru 499,999     17-SEP-10
# 143581  Cities from 250,000 thru 499,999     21-SEP-10
# 143582  Cities from 250,000 thru 499,999     01-OCT-10
# ...                                  ...           ...
# 219068    Cities from 10,000 thru 24,999     29-NOV-20
# 219069    Cities from 10,000 thru 24,999     14-JUL-20
# 219070    Cities from 10,000 thru 24,999     16-OCT-20
# 219071    Cities from 10,000 thru 24,999     30-JAN-20
# 219072    Cities from 10,000 thru 24,999     21-NOV-20
#
#                            OFFENDER_RACE  VICTIM_COUNT  \
# 143578                             White             2
# 143579         Black or African American             1
# 143580  American Indian or Alaska Native             2
# 143581  American Indian or Alaska Native             1
# 143582                             White             1
# ...                                  ...           ...
# 219068                             White             2
# 219069                           Unknown             1
# 219070         Black or African American             1
# 219071                             White             1
# 219072                             White             1
#
#                                     OFFENSE_NAME  \
# 143578                        Aggravated Assault
# 143579                            Simple Assault
# 143580                            Simple Assault
# 143581                        Aggravated Assault
# 143582                              Intimidation
# ...                                          ...
# 219068                              Intimidation
# 219069  Destruction/Damage/Vandalism of Property
# 219070                        Aggravated Assault
# 219071                            Simple Assault
# 219072                       Theft From Building
#
#                                OFFENSE_NAME_1(;)  \
# 143578                        Aggravated Assault
# 143579                            Simple Assault
# 143580                            Simple Assault
# 143581                        Aggravated Assault
# 143582                              Intimidation
# ...                                          ...
# 219068                              Intimidation
# 219069  Destruction/Damage/Vandalism of Property
# 219070                        Aggravated Assault
# 219071                            Simple Assault
# 219072                       Theft From Building
#
#                                         LOCATION_NAME LOCATION_NAME_1(/)  \
# 143578             Highway/Road/Alley/Street/Sidewalk            Highway
# 143579  Jail/Prison/Penitentiary/Corrections Facility               Jail
# 143580                                   Liquor Store       Liquor Store
# 143581                                 Residence/Home          Residence
# 143582             Highway/Road/Alley/Street/Sidewalk            Highway
# ...                                               ...                ...
# 219068                                Park/Playground               Park
# 219069                                Park/Playground               Park
# 219070                                 Residence/Home          Residence
# 219071                                 Residence/Home          Residence
# 219072                                 Residence/Home          Residence
#
#                                    LOCATION_NAME_2(;)  \
# 143578             Highway/Road/Alley/Street/Sidewalk
# 143579  Jail/Prison/Penitentiary/Corrections Facility
# 143580                                   Liquor Store
# 143581                                 Residence/Home
# 143582             Highway/Road/Alley/Street/Sidewalk
# ...                                               ...
# 219068                                Park/Playground
# 219069                                Park/Playground
# 219070                                 Residence/Home
# 219071                                 Residence/Home
# 219072                                 Residence/Home
#
#                                                 BIAS_DESC  \
# 143578                     Anti-Black or African American
# 143579                                    Anti-Gay (Male)
# 143580                                         Anti-White
# 143581                                         Anti-White
# 143582                              Anti-Islamic (Muslim)
# ...                                                   ...
# 219068  Anti-Lesbian, Gay, Bisexual, or Transgender (M...
# 219069                                         Anti-White
# 219070                                         Anti-White
# 219071                                        Anti-Female
# 219072                         Anti-Gender Non-Conforming
#
#                                            BIAS_DESC_1(;) VICTIM_TYPES
# 143578                     Anti-Black or African American   Individual
# 143579                                    Anti-Gay (Male)   Individual
# 143580                                         Anti-White   Individual
# 143581                                         Anti-White   Individual
# 143582                              Anti-Islamic (Muslim)   Individual
# ...                                                   ...          ...
# 219068  Anti-Lesbian, Gay, Bisexual, or Transgender (M...   Individual
# 219069                                         Anti-White   Government
# 219070                                         Anti-White   Individual
# 219071                                        Anti-Female   Individual
# 219072                         Anti-Gender Non-Conforming   Individual
#
# [75495 rows x 16 columns]

# %%
projyr2_df.to_csv("Final_output2.csv", index=False, header=True)

# %%
# to create a snsplot of all the columns in the dataset
for col2 in thirdhousing.columns:
    sns.boxplot(data=thirdhousing[col2], y=thirdhousing[col2])
    plt.show()

# %%
projyr2_df.groupby("OFFENDER_RACE")

# %%
df_bub1 = projyr2_df.groupby(['OFFENDER_RACE'])['OFFENDER_RACE'].count()
df_bub1
# Out:
# OFFENDER_RACE
# American Indian or Alaska Native               504
# Asian                                          556
# Black or African American                    10936
# Multiple                                      1979
# Native Hawaiian or Other Pacific Islander       83
# Unknown                                      32423
# White                                        28994
# Name: OFFENDER_RACE, dtype: int64

# %%
projyr2_df.head()
# Out:
#         DATA_YEAR STATE_ABBR STATE_NAME REGION_NAME  \
# 143578       2010         AK     Alaska        West
# 143579       2010         AK     Alaska        West
# 143580       2010         AK     Alaska        West
# 143581       2010         AK     Alaska        West
# 143582       2010         AK     Alaska        West
#
#                    POPULATION_GROUP_DESC INCIDENT_DATE  \
# 143578  Cities from 250,000 thru 499,999     14-JUL-10
# 143579  Cities from 250,000 thru 499,999     14-JUL-10
# 143580  Cities from 250,000 thru 499,999     17-SEP-10
# 143581  Cities from 250,000 thru 499,999     21-SEP-10
# 143582  Cities from 250,000 thru 499,999     01-OCT-10
#
#                            OFFENDER_RACE  VICTIM_COUNT        OFFENSE_NAME  \
# 143578                             White             2  Aggravated Assault
# 143579         Black or African American             1      Simple Assault
# 143580  American Indian or Alaska Native             2      Simple Assault
# 143581  American Indian or Alaska Native             1  Aggravated Assault
# 143582                             White             1        Intimidation
#
#          OFFENSE_NAME_1(;)                                  LOCATION_NAME  \
# 143578  Aggravated Assault             Highway/Road/Alley/Street/Sidewalk
# 143579      Simple Assault  Jail/Prison/Penitentiary/Corrections Facility
# 143580      Simple Assault                                   Liquor Store
# 143581  Aggravated Assault                                 Residence/Home
# 143582        Intimidation             Highway/Road/Alley/Street/Sidewalk
#
#        LOCATION_NAME_1(/)                             LOCATION_NAME_2(;)  \
# 143578            Highway             Highway/Road/Alley/Street/Sidewalk
# 143579               Jail  Jail/Prison/Penitentiary/Corrections Facility
# 143580       Liquor Store                                   Liquor Store
# 143581          Residence                                 Residence/Home
# 143582            Highway             Highway/Road/Alley/Street/Sidewalk
#
#                              BIAS_DESC                  BIAS_DESC_1(;)  \
# 143578  Anti-Black or African American  Anti-Black or African American
# 143579                 Anti-Gay (Male)                 Anti-Gay (Male)
# 143580                      Anti-White                      Anti-White
# 143581                      Anti-White                      Anti-White
# 143582           Anti-Islamic (Muslim)           Anti-Islamic (Muslim)
#
#        VICTIM_TYPES
# 143578   Individual
# 143579   Individual
# 143580   Individual
# 143581   Individual
# 143582   Individual

# %%
bub_df = projyr2_df.groupby(["DATA_YEAR", "OFFENDER_RACE"]).agg({"OFFENDER_RACE":"count", "VICTIM_COUNT":"sum"}, axis=1)
bub_df
# Out:
#                                                      OFFENDER_RACE  \
# DATA_YEAR OFFENDER_RACE
# 2010      American Indian or Alaska Native                      42
#           Asian                                                 47
#           Black or African American                            739
#           Multiple                                             180
#           Unknown                                             3062
# ...                                                            ...
# 2020      Black or African American                           1260
#           Multiple                                             177
#           Native Hawaiian or Other Pacific Islander             27
#           Unknown                                             4507
#           White                                               3675
#
#                                                      VICTIM_COUNT
# DATA_YEAR OFFENDER_RACE
# 2010      American Indian or Alaska Native                     53
#           Asian                                                64
#           Black or African American                           930
#           Multiple                                            253
#           Unknown                                            3615
# ...                                                           ...
# 2020      Black or African American                          1500
#           Multiple                                            251
#           Native Hawaiian or Other Pacific Islander            34
#           Unknown                                            5472
#           White                                              5698
#
# [74 rows x 2 columns]

# %%
# year, state and race
# bub_df = projyr2_df.groupby(["DATA_YEAR", "OFFENDER_RACE"]).agg({"OFFENDER_RACE":"count", "VICTIM_COUNT":"sum"}, axis=1)
# bub_df

# %%
# bubble graph of offender race "OFFENDER_RACE" by
# by number of incidents (each row is an incident so count of each row)

# number of incidents VS VICTIM_COUNT

# size="pop", 

plt.figure(figsize=(14,8))

# Set your x and y limits
# plt.xlim(-0.1, 130)
plt.ylim(0, 1000)

sns.scatterplot(data=projyr2_df, x="OFFENDER_RACE", y="OFFENDER_RACE", size="VICTIM_COUNT", legend=False, sizes=(20, 2000), alpha= 0.5)

plt.show()

# %%
# bubble graph of offender race "OFFENDER_RACE" by
# by number of incidents (each row is an incident so count of each row)

# number of incidents VS VICTIM_COUNT

# size="pop", 

plt.figure(figsize=(14,8))

# Set your x and y limits
# plt.xlim(-0.1, 130)
# plt.ylim(-5, 1000)

sns.scatterplot(data=projyr2_df, x="OFFENDER_RACE", y="VICTIM_COUNT", size="OFFENDER_RACE", legend=False, sizes=(20, 2000), alpha= 0.5)

# plt.legend()

plt.show()

# %%
# bubble graph of offender race "OFFENDER_RACE" by
# by number of incidents (each row is an incident so count of each row)

# number of incidents VS VICTIM_COUNT

# size="pop", 

plt.figure(figsize=(14,8))

# Set your x and y limits
# plt.xlim(-0.1, 130)
# plt.ylim(-5, 1000)

sns.scatterplot(data=projyr2_df, x="OFFENDER_RACE", y="VICTIM_COUNT", size="OFFENDER_RACE", legend=False, sizes=(20, 2000), alpha= 0.5)

# plt.legend()

plt.show()
# Out:
#           DATA_YEAR  VICTIM_COUNT
# count  75495.000000  75495.000000
# mean    2015.359547      1.240612
# std        3.290125      3.561156
# min     2010.000000      1.000000
# 25%     2012.000000      1.000000
# 50%     2016.000000      1.000000
# 75%     2018.000000      1.000000
# max     2020.000000    900.000000
