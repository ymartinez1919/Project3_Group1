# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# we are going with the last decade 2010 through 2020

filepath2 = "hatecrimes_2010_2020.csv"

# %%
# read in dataset into pandas
df = pd.read_csv(filepath2)

df.info()
# Out:
# C:\Users\yvargas\Downloads\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219073 entries, 0 to 219072
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   INCIDENT_ID               219073 non-null  int64
#  1   DATA_YEAR                 219073 non-null  int64
#  2   ORI                       219073 non-null  object
#  3   PUB_AGENCY_NAME           219073 non-null  object
#  4   PUB_AGENCY_UNIT           6427 non-null    object
#  5   AGENCY_TYPE_NAME          219073 non-null  object
#  6   STATE_ABBR                219073 non-null  object
#  7   STATE_NAME                219073 non-null  object
#  8   DIVISION_NAME             219073 non-null  object
# ...

# %%
# retrieve the columns in the dataset
df.columns
# Out:
# Index(['INCIDENT_ID', 'DATA_YEAR', 'ORI', 'PUB_AGENCY_NAME', 'PUB_AGENCY_UNIT',
#        'AGENCY_TYPE_NAME', 'STATE_ABBR', 'STATE_NAME', 'DIVISION_NAME',
#        'REGION_NAME', 'POPULATION_GROUP_CODE', 'POPULATION_GROUP_DESC',
#        'INCIDENT_DATE', 'ADULT_VICTIM_COUNT', 'JUVENILE_VICTIM_COUNT',
#        'TOTAL_OFFENDER_COUNT', 'ADULT_OFFENDER_COUNT',
#        'JUVENILE_OFFENDER_COUNT', 'OFFENDER_RACE', 'OFFENDER_ETHNICITY',
#        'VICTIM_COUNT', 'OFFENSE_NAME', 'TOTAL_INDIVIDUAL_VICTIMS',
#        'LOCATION_NAME', 'BIAS_DESC', 'VICTIM_TYPES', 'MULTIPLE_OFFENSE',
#        'MULTIPLE_BIAS'],
#       dtype='object')

# %%
# create a dataset with the columns selected
cols = ['INCIDENT_ID',"DATA_YEAR","STATE_ABBR","STATE_NAME","REGION_NAME","POPULATION_GROUP_DESC","INCIDENT_DATE","OFFENDER_RACE","VICTIM_COUNT","OFFENSE_NAME","LOCATION_NAME","BIAS_DESC","VICTIM_TYPES"]
df1 = df.loc[:, cols]
df1
# Out:
#         INCIDENT_ID  DATA_YEAR STATE_ABBR STATE_NAME REGION_NAME  \
# 0              3015       1991         AR   Arkansas       South
# 1              3016       1991         AR   Arkansas       South
# 2                43       1991         AR   Arkansas       South
# 3                44       1991         AR   Arkansas       South
# 4              3017       1991         AR   Arkansas       South
# ...             ...        ...        ...        ...         ...
# 219068      1318026       2020         WY    Wyoming        West
# 219069      1142103       2020         WY    Wyoming        West
# 219070      1318018       2020         WY    Wyoming        West
# 219071      1318022       2020         WY    Wyoming        West
# 219072      1318023       2020         WY    Wyoming        West
#
#                  POPULATION_GROUP_DESC INCIDENT_DATE  \
# 0       Cities from 10,000 thru 24,999     31-AUG-91
# 1         Cities from 2,500 thru 9,999     19-SEP-91
# ...

# %%
# filter for DATA_YEAR greater than 2010
mask = (df1["DATA_YEAR"] >= 2015)
df2 = df1.loc[mask, :]
df2
# Out:
#         INCIDENT_ID  DATA_YEAR STATE_ABBR STATE_NAME REGION_NAME  \
# 174747       180579       2015         AK     Alaska        West
# 174748       180580       2015         AK     Alaska        West
# 174749       180581       2015         AK     Alaska        West
# 174750       180582       2015         AK     Alaska        West
# 174751       180583       2015         AK     Alaska        West
# ...             ...        ...        ...        ...         ...
# 219068      1318026       2020         WY    Wyoming        West
# 219069      1142103       2020         WY    Wyoming        West
# 219070      1318018       2020         WY    Wyoming        West
# 219071      1318022       2020         WY    Wyoming        West
# 219072      1318023       2020         WY    Wyoming        West
#
#                    POPULATION_GROUP_DESC INCIDENT_DATE  \
# 174747  Cities from 250,000 thru 499,999     28-MAR-15
# 174748  Cities from 250,000 thru 499,999     20-NOV-15
# ...

# %%
#projyr_df.to_csv("Final_output.csv", index=False, header=True)

# %%
df2["OFFENSE_NAME"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 174747    Destruction/Damage/Vandalism of Property
# 174748                                Intimidation
# 174749                                Intimidation
# 174750                                       Arson
# 174751                          Aggravated Assault
#                             ...
# 219068                                Intimidation
# 219069    Destruction/Damage/Vandalism of Property
# 219070                          Aggravated Assault
# 219071                              Simple Assault
# 219072                         Theft From Building
# Name: OFFENSE_NAME, Length: 44326, dtype: object>

# %%
df2.columns
# Out:
# Index(['INCIDENT_ID', 'DATA_YEAR', 'STATE_ABBR', 'STATE_NAME', 'REGION_NAME',
#        'POPULATION_GROUP_DESC', 'INCIDENT_DATE', 'OFFENDER_RACE',
#        'VICTIM_COUNT', 'OFFENSE_NAME', 'LOCATION_NAME', 'BIAS_DESC',
#        'VICTIM_TYPES'],
#       dtype='object')

# %%
#df2['LOCATION_NAME_1(/)'] = df2['LOCATION_NAME'].str.split("/").str[0]

# %%
df2
# Out:
#         INCIDENT_ID  DATA_YEAR STATE_ABBR STATE_NAME REGION_NAME  \
# 174747       180579       2015         AK     Alaska        West
# 174748       180580       2015         AK     Alaska        West
# 174749       180581       2015         AK     Alaska        West
# 174750       180582       2015         AK     Alaska        West
# 174751       180583       2015         AK     Alaska        West
# ...             ...        ...        ...        ...         ...
# 219068      1318026       2020         WY    Wyoming        West
# 219069      1142103       2020         WY    Wyoming        West
# 219070      1318018       2020         WY    Wyoming        West
# 219071      1318022       2020         WY    Wyoming        West
# 219072      1318023       2020         WY    Wyoming        West
#
#                    POPULATION_GROUP_DESC INCIDENT_DATE  \
# 174747  Cities from 250,000 thru 499,999     28-MAR-15
# 174748  Cities from 250,000 thru 499,999     20-NOV-15
# ...

# %%
df2['LOCATION_NAME_2(;)'] = df2['LOCATION_NAME'].str.split(";").str[0]
# Out:
# C:\Users\yvargas\AppData\Local\Temp/ipykernel_16912/2634079572.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['LOCATION_NAME_2(;)'] = df2['LOCATION_NAME'].str.split(";").str[0]

# %%
df2
# Out:
#         INCIDENT_ID  DATA_YEAR STATE_ABBR STATE_NAME REGION_NAME  \
# 174747       180579       2015         AK     Alaska        West
# 174748       180580       2015         AK     Alaska        West
# 174749       180581       2015         AK     Alaska        West
# 174750       180582       2015         AK     Alaska        West
# 174751       180583       2015         AK     Alaska        West
# ...             ...        ...        ...        ...         ...
# 219068      1318026       2020         WY    Wyoming        West
# 219069      1142103       2020         WY    Wyoming        West
# 219070      1318018       2020         WY    Wyoming        West
# 219071      1318022       2020         WY    Wyoming        West
# 219072      1318023       2020         WY    Wyoming        West
#
#                    POPULATION_GROUP_DESC INCIDENT_DATE  \
# 174747  Cities from 250,000 thru 499,999     28-MAR-15
# 174748  Cities from 250,000 thru 499,999     20-NOV-15
# ...

# %%
df2['OFFENSE_NAME_1(;)'] = df2['OFFENSE_NAME'].str.split(";").str[0]
# Out:
# C:\Users\yvargas\AppData\Local\Temp/ipykernel_16912/3454724527.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['OFFENSE_NAME_1(;)'] = df2['OFFENSE_NAME'].str.split(";").str[0]

# %%
df2['BIAS_DESC_1(;)'] = df2['BIAS_DESC'].str.split(";").str[0]
# Out:
# C:\Users\yvargas\AppData\Local\Temp/ipykernel_16912/2050300805.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['BIAS_DESC_1(;)'] = df2['BIAS_DESC'].str.split(";").str[0]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44326 entries, 174747 to 219072
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   INCIDENT_ID            44326 non-null  int64
#  1   DATA_YEAR              44326 non-null  int64
#  2   STATE_ABBR             44326 non-null  object
#  3   STATE_NAME             44326 non-null  object
#  4   REGION_NAME            44326 non-null  object
#  5   POPULATION_GROUP_DESC  44326 non-null  object
#  6   INCIDENT_DATE          44326 non-null  object
#  7   OFFENDER_RACE          44306 non-null  object
#  8   VICTIM_COUNT           44326 non-null  int64
#  9   OFFENSE_NAME           44326 non-null  object
#  10  LOCATION_NAME          44326 non-null  object
#  11  BIAS_DESC              44326 non-null  object
#  12  VICTIM_TYPES           44326 non-null  object
#  13  LOCATION_NAME_2(;)     44326 non-null  object
# ...

# %%
df2.columns
# Out:
# Index(['INCIDENT_ID', 'DATA_YEAR', 'STATE_ABBR', 'STATE_NAME', 'REGION_NAME',
#        'POPULATION_GROUP_DESC', 'INCIDENT_DATE', 'OFFENDER_RACE',
#        'VICTIM_COUNT', 'OFFENSE_NAME', 'LOCATION_NAME', 'BIAS_DESC',
#        'VICTIM_TYPES', 'LOCATION_NAME_2(;)', 'OFFENSE_NAME_1(;)',
#        'BIAS_DESC_1(;)'],
#       dtype='object')

# %%
# cols2 = ['DATA_YEAR', "INCIDENT_ID", 'STATE_ABBR', 'STATE_NAME', 'REGION_NAME','POPULATION_GROUP_DESC', 'INCIDENT_DATE', 'OFFENDER_RACE','VICTIM_COUNT', 'OFFENSE_NAME', 'OFFENSE_NAME_1(/)', 'LOCATION_NAME','LOCATION_NAME_1(/)', 'LOCATION_NAME_2(;)','BIAS_DESC','BIAS_DESC_1(/)','VICTIM_TYPES']
# projyr2_df = projyr_df.loc[:, cols2]
# projyr2_df

# %%
df2.to_csv("Final_output3.csv", index=False, header=True)

# %%
# cols2 = ['DATA_YEAR', 'STATE_ABBR', 'STATE_NAME', 'REGION_NAME','POPULATION_GROUP_DESC', 'INCIDENT_DATE', 'OFFENDER_RACE','VICTIM_COUNT', 'OFFENSE_NAME', 'OFFENSE_NAME_1(;)','LOCATION_NAME','LOCATION_NAME_1(/)','LOCATION_NAME_2(;)','BIAS_DESC','BIAS_DESC_1(;)','VICTIM_TYPES']
# projyr2_df = projyr2_df.loc[:, cols2]
# projyr2_df

# %%
df2.columns
# Out:
# Index(['INCIDENT_ID', 'DATA_YEAR', 'STATE_ABBR', 'STATE_NAME', 'REGION_NAME',
#        'POPULATION_GROUP_DESC', 'INCIDENT_DATE', 'OFFENDER_RACE',
#        'VICTIM_COUNT', 'OFFENSE_NAME', 'LOCATION_NAME', 'BIAS_DESC',
#        'VICTIM_TYPES', 'LOCATION_NAME_2(;)', 'OFFENSE_NAME_1(;)',
#        'BIAS_DESC_1(;)'],
#       dtype='object')

# %%
sum_df = df2.groupby(["DATA_YEAR", "BIAS_DESC_1(;)",  "OFFENDER_RACE", "OFFENSE_NAME_1(;)"]).agg({"INCIDENT_ID":"size", "VICTIM_COUNT":"sum"}, axis=1).reset_index()
sum_df.columns = ['DATA_YEAR', 'BIAS_DESC_1(;)', 'OFFENDER_RACE','OFFENSE_NAME_1(;)', "count", 'Victim_sum']
sum_df.head(20)
# Out:
#     DATA_YEAR                         BIAS_DESC_1(;)  \
# 0        2015  Anti-American Indian or Alaska Native
# 1        2015  Anti-American Indian or Alaska Native
# 2        2015  Anti-American Indian or Alaska Native
# 3        2015  Anti-American Indian or Alaska Native
# 4        2015  Anti-American Indian or Alaska Native
# 5        2015  Anti-American Indian or Alaska Native
# 6        2015  Anti-American Indian or Alaska Native
# 7        2015  Anti-American Indian or Alaska Native
# 8        2015  Anti-American Indian or Alaska Native
# 9        2015  Anti-American Indian or Alaska Native
# 10       2015  Anti-American Indian or Alaska Native
# 11       2015  Anti-American Indian or Alaska Native
# 12       2015  Anti-American Indian or Alaska Native
# 13       2015  Anti-American Indian or Alaska Native
# 14       2015  Anti-American Indian or Alaska Native
# 15       2015  Anti-American Indian or Alaska Native
# 16       2015  Anti-American Indian or Alaska Native
# ...

# %%
sum_df.head()
# Out:
#    DATA_YEAR                         BIAS_DESC_1(;)  \
# 0       2015  Anti-American Indian or Alaska Native
# 1       2015  Anti-American Indian or Alaska Native
# 2       2015  Anti-American Indian or Alaska Native
# 3       2015  Anti-American Indian or Alaska Native
# 4       2015  Anti-American Indian or Alaska Native
#
#                       OFFENDER_RACE    OFFENSE_NAME_1(;)  count  Victim_sum
# 0  American Indian or Alaska Native   Aggravated Assault      3           3
# 1  American Indian or Alaska Native  Motor Vehicle Theft      1           1
# 2  American Indian or Alaska Native          Shoplifting      1           1
# 3  American Indian or Alaska Native       Simple Assault      3           6
# 4                             Asian         Intimidation      1           1

# %%
sum_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5054 entries, 0 to 5053
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   DATA_YEAR          5054 non-null   int64
#  1   BIAS_DESC_1(;)     5054 non-null   object
#  2   OFFENDER_RACE      5054 non-null   object
#  3   OFFENSE_NAME_1(;)  5054 non-null   object
#  4   count              5054 non-null   int64
#  5   Victim_sum         5054 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 237.0+ KB

# %%
# year, state and race
# bub_df = projyr2_df.groupby(["DATA_YEAR", "OFFENDER_RACE"]).agg({"OFFENDER_RACE":"count", "VICTIM_COUNT":"sum"}, axis=1)
# bub_df

# %%
# bubble graph of offender race "OFFENDER_RACE" by
# by number of incidents (each row is an incident so count of each row)

# number of incidents VS VICTIM_COUNT

# size="pop", 

plt.figure(figsize=(14,8))

# Set your x and y limits
# plt.xlim(-0.1, 130)
plt.ylim(0, 1000)

sns.scatterplot(data=sum_df, x="OFFENDER_RACE", y="count", size="Victim_sum", legend=False, sizes=(20, 2000), alpha= 0.5)

plt.show()

# %%
ax = sns.barplot(x="OFFENDER_RACE", y="count", data=sum_df)

# %%
sum_df.head(20)
# Out:
#     DATA_YEAR                         BIAS_DESC_1(;)  \
# 0        2015  Anti-American Indian or Alaska Native
# 1        2015  Anti-American Indian or Alaska Native
# 2        2015  Anti-American Indian or Alaska Native
# 3        2015  Anti-American Indian or Alaska Native
# 4        2015  Anti-American Indian or Alaska Native
# 5        2015  Anti-American Indian or Alaska Native
# 6        2015  Anti-American Indian or Alaska Native
# 7        2015  Anti-American Indian or Alaska Native
# 8        2015  Anti-American Indian or Alaska Native
# 9        2015  Anti-American Indian or Alaska Native
# 10       2015  Anti-American Indian or Alaska Native
# 11       2015  Anti-American Indian or Alaska Native
# 12       2015  Anti-American Indian or Alaska Native
# 13       2015  Anti-American Indian or Alaska Native
# 14       2015  Anti-American Indian or Alaska Native
# 15       2015  Anti-American Indian or Alaska Native
# 16       2015  Anti-American Indian or Alaska Native
# ...

# %%
sum_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5054 entries, 0 to 5053
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   DATA_YEAR          5054 non-null   int64
#  1   BIAS_DESC_1(;)     5054 non-null   object
#  2   OFFENDER_RACE      5054 non-null   object
#  3   OFFENSE_NAME_1(;)  5054 non-null   object
#  4   count              5054 non-null   int64
#  5   Victim_sum         5054 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 237.0+ KB

# %%
fig = plt.figure(figsize=(12,10))
ax = sns.barplot(x="count", y="OFFENSE_NAME_1(;)", data=sum_df)

# %%
df2.columns
# Out:
# Index(['INCIDENT_ID', 'DATA_YEAR', 'STATE_ABBR', 'STATE_NAME', 'REGION_NAME',
#        'POPULATION_GROUP_DESC', 'INCIDENT_DATE', 'OFFENDER_RACE',
#        'VICTIM_COUNT', 'OFFENSE_NAME', 'LOCATION_NAME', 'BIAS_DESC',
#        'VICTIM_TYPES', 'LOCATION_NAME_2(;)', 'OFFENSE_NAME_1(;)',
#        'BIAS_DESC_1(;)'],
#       dtype='object')

# %%
sum_df_bar = df2.groupby(["DATA_YEAR","OFFENSE_NAME_1(;)", "BIAS_DESC_1(;)", "OFFENDER_RACE"]).agg({"INCIDENT_ID":"size", "VICTIM_COUNT":"sum"}, axis=1).reset_index()
sum_df_bar.columns = ["Year", "Crime_Type", "Bias_Type", "Offender_Race", "Count", "Victim_Sum"]
sum_df_bar.head(20)
# Out:
#     Year          Crime_Type                                      Bias_Type  \
# 0   2015  Aggravated Assault          Anti-American Indian or Alaska Native
# 1   2015  Aggravated Assault          Anti-American Indian or Alaska Native
# 2   2015  Aggravated Assault          Anti-American Indian or Alaska Native
# 3   2015  Aggravated Assault                                      Anti-Arab
# 4   2015  Aggravated Assault                                      Anti-Arab
# 5   2015  Aggravated Assault                                     Anti-Asian
# 6   2015  Aggravated Assault                                     Anti-Asian
# 7   2015  Aggravated Assault                                     Anti-Asian
# 8   2015  Aggravated Assault                                     Anti-Asian
# 9   2015  Aggravated Assault                                     Anti-Asian
# 10  2015  Aggravated Assault                                  Anti-Bisexual
# ...

# %%
fig = plt.figure(figsize=(12,10))
ax = sns.barplot(x="Count", y="Crime_Type", data=sum_df_bar)

# %%
sum_df_bar2 = sum_df_bar.groupby(["Crime_Type"]).agg({"Count":"size"}, axis=1).reset_index()
sum_df_bar2
# Out:
#                                      Crime_Type  Count
# 0                            Aggravated Assault    535
# 1                             All Other Larceny    277
# 2                                Animal Cruelty      6
# 3                                         Arson    146
# 4           Assisting or Promoting Prostitution      2
# 5                              Betting/Wagering      1
# 6                                       Bribery      1
# 7                  Burglary/Breaking & Entering    297
# 8                        Counterfeiting/Forgery     53
# 9    Credit Card/Automated Teller Machine Fraud     54
# 10     Destruction/Damage/Vandalism of Property    582
# 11                    Drug Equipment Violations    121
# 12                     Drug/Narcotic Violations    169
# 13                                 Embezzlement     17
# 14                          Extortion/Blackmail     14
# 15      False Pretenses/Swindle/Confidence Game     79
# ...

# %%
sum_df_crime = df2.groupby(["DATA_YEAR","OFFENSE_NAME_1(;)"]).agg({"INCIDENT_ID":"size"}, axis=1).reset_index()
sum_df_crime.columns = ["Year", "Crime_Type", "Count"]
sum_df_crime.head(20)
# Out:
#     Year                                  Crime_Type  Count
# 0   2015                          Aggravated Assault    680
# 1   2015                           All Other Larceny    110
# 2   2015                                       Arson     29
# 3   2015                Burglary/Breaking & Entering    141
# 4   2015                      Counterfeiting/Forgery      6
# 5   2015  Credit Card/Automated Teller Machine Fraud     13
# 6   2015    Destruction/Damage/Vandalism of Property   1673
# 7   2015                   Drug Equipment Violations     16
# 8   2015                    Drug/Narcotic Violations     27
# 9   2015                                Embezzlement      5
# 10  2015                         Extortion/Blackmail      1
# 11  2015     False Pretenses/Swindle/Confidence Game     15
# 12  2015                                    Fondling      3
# 13  2015                               Impersonation     16
# 14  2015                                Intimidation   1455
# ...

# %%
sum_df_Race = df2.groupby(["DATA_YEAR", "OFFENDER_RACE"]).agg({"INCIDENT_ID":"size", "VICTIM_COUNT":"sum"}, axis=1).reset_index()
sum_df_Race.columns = ["Year", "Offender_Race", "Count", "Victim_Sum"]
sum_df_Race.head(20)
# Out:
#     Year                              Offender_Race  Count  Victim_Sum
# 0   2015           American Indian or Alaska Native     46          66
# 1   2015                                      Asian     48          61
# 2   2015                  Black or African American    956        1168
# 3   2015                                   Multiple    209         309
# 4   2015  Native Hawaiian or Other Pacific Islander      4           7
# 5   2015                                    Unknown   2410        2733
# 6   2015                                      White   2198        2862
# 7   2016           American Indian or Alaska Native     42          53
# 8   2016                                      Asian     38          45
# 9   2016                  Black or African American   1090        1405
# 10  2016                                   Multiple    180         257
# 11  2016  Native Hawaiian or Other Pacific Islander      7           7
# ...

# %%
sum_df_Race = df2.groupby(["DATA_YEAR", "OFFENDER_RACE"]).agg({"INCIDENT_ID":"size", "VICTIM_COUNT":"sum"}, axis=1).reset_index()
sum_df_Race.columns = ["Year", "Offender_Race", "Count", "Victim_Sum"]
# sum_df_Race.head(20)

# %%
df2.head()
# Out:
#         INCIDENT_ID  DATA_YEAR STATE_ABBR STATE_NAME REGION_NAME  \
# 174747       180579       2015         AK     Alaska        West
# 174748       180580       2015         AK     Alaska        West
# 174749       180581       2015         AK     Alaska        West
# 174750       180582       2015         AK     Alaska        West
# 174751       180583       2015         AK     Alaska        West
#
#                    POPULATION_GROUP_DESC INCIDENT_DATE  \
# 174747  Cities from 250,000 thru 499,999     28-MAR-15
# 174748  Cities from 250,000 thru 499,999     20-NOV-15
# 174749  Cities from 250,000 thru 499,999     31-JUL-15
# 174750  Cities from 250,000 thru 499,999     11-JUN-15
# 174751  Cities from 250,000 thru 499,999     03-AUG-15
#
#                            OFFENDER_RACE  VICTIM_COUNT  \
# 174747                           Unknown             2
# 174748  American Indian or Alaska Native             1
# 174749  American Indian or Alaska Native            10
# ...

# %%
sum_df_bias = df2.groupby(["DATA_YEAR","REGION_NAME", "BIAS_DESC_1(;)"]).agg({"INCIDENT_ID":"size"}, axis=1).reset_index()
sum_df_bias.columns = ["Year", "Region_Name", "Bias_Desc", "Count"]
sum_df_bias
# Out:
#      Year Region_Name                              Bias_Desc  Count
# 0    2015     Midwest  Anti-American Indian or Alaska Native     79
# 1    2015     Midwest                              Anti-Arab      6
# 2    2015     Midwest                             Anti-Asian     19
# 3    2015     Midwest               Anti-Atheism/Agnosticism      1
# 4    2015     Midwest                          Anti-Bisexual     13
# ..    ...         ...                                    ...    ...
# 823  2020        West               Anti-Physical Disability     17
# 824  2020        West                        Anti-Protestant     15
# 825  2020        West                              Anti-Sikh     19
# 826  2020        West                       Anti-Transgender    101
# 827  2020        West                             Anti-White    290
#
# [828 rows x 4 columns]

# %%
sum_df_bias
# Out:
#      Year Region_Name                              Bias_Desc  Count
# 0    2015     Midwest  Anti-American Indian or Alaska Native     79
# 1    2015     Midwest                              Anti-Arab      6
# 2    2015     Midwest                             Anti-Asian     19
# 3    2015     Midwest               Anti-Atheism/Agnosticism      1
# 4    2015     Midwest                          Anti-Bisexual     13
# ..    ...         ...                                    ...    ...
# 823  2020        West               Anti-Physical Disability     17
# 824  2020        West                        Anti-Protestant     15
# 825  2020        West                              Anti-Sikh     19
# 826  2020        West                       Anti-Transgender    101
# 827  2020        West                             Anti-White    290
#
# [828 rows x 4 columns]

# %%
sum_df_map = df2.groupby(["DATA_YEAR", "STATE_NAME"]).agg({"INCIDENT_ID":"size"}, axis=1).reset_index()
sum_df_map.columns = ["Year", "State", "Count"]

# %%
sum_df_map
# Out:
#      Year          State  Count
# 0    2015        Alabama     10
# 1    2015         Alaska      8
# 2    2015        Arizona    276
# 3    2015       Arkansas      6
# 4    2015     California    837
# ..    ...            ...    ...
# 300  2020       Virginia    187
# 301  2020     Washington    451
# 302  2020  West Virginia     82
# 303  2020      Wisconsin    157
# 304  2020        Wyoming     18
#
# [305 rows x 3 columns]

# %%
#sum_df_map.to_csv("HateCrime_map.csv",  index=False, header=True)

# %%
#sum_df_Race.to_csv("HateCrime_Race.csv",  index=False, header=True)

# %%
#sum_df_crime.to_csv("HateCrime_CrimeType.csv",  index=False, header=True)

# %%
sum_df_bias.to_csv("HateCrime_bias1.csv",  index=False, header=True)

# %%
df = pd.read_csv (r'C:/Users/yvargas/Desktop/SMU/Project3/HateCrime_CrimeType.csv')
df.to_json (r'C:/Users/yvargas/Desktop/SMU\Project3/HateCrime_CrimeType.json')

# %%
csvFilePath = r'C:/Users/yvargas/Desktop/SMU/Project3/HateCrime_CrimeType.csv'
jsonFilePath = r'C:/Users/yvargas/Desktop/SMU\Project3/HateCrime_CrimeType.json'
