# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filepath = "hatecrimes_1991_2020.csv"

# %%
# we are going with the last decade 2010 through 2020

filepath2 = "hatecrimes_2010_2020.csv"

# %%
df = pd.read_csv(filepath)

df.info()
# Out:
# C:\Users\jonwukeme\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219073 entries, 0 to 219072
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   INCIDENT_ID               219073 non-null  int64
#  1   DATA_YEAR                 219073 non-null  int64
#  2   ORI                       219073 non-null  object
#  3   PUB_AGENCY_NAME           219073 non-null  object
#  4   PUB_AGENCY_UNIT           6427 non-null    object
#  5   AGENCY_TYPE_NAME          219073 non-null  object
#  6   STATE_ABBR                219073 non-null  object
#  7   STATE_NAME                219073 non-null  object
#  8   DIVISION_NAME             219073 non-null  object
# ...

# %%
df2 = pd.read_csv(filepath2)

df2.info()
# Out:
# C:\Users\jonwukeme\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219073 entries, 0 to 219072
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   INCIDENT_ID               219073 non-null  int64
#  1   DATA_YEAR                 219073 non-null  int64
#  2   ORI                       219073 non-null  object
#  3   PUB_AGENCY_NAME           219073 non-null  object
#  4   PUB_AGENCY_UNIT           6427 non-null    object
#  5   AGENCY_TYPE_NAME          219073 non-null  object
#  6   STATE_ABBR                219073 non-null  object
#  7   STATE_NAME                219073 non-null  object
#  8   DIVISION_NAME             219073 non-null  object
# ...

# %%
df.head(20)
# Out:
#     INCIDENT_ID  DATA_YEAR        ORI    PUB_AGENCY_NAME PUB_AGENCY_UNIT  \
# 0          3015       1991  AR0040200             Rogers             NaN
# 1          3016       1991  AR0290100               Hope             NaN
# 2            43       1991  AR0350100         Pine Bluff             NaN
# 3            44       1991  AR0350100         Pine Bluff             NaN
# 4          3017       1991  AR0350100         Pine Bluff             NaN
# 5          3018       1991  AR0350100         Pine Bluff             NaN
# 6          3019       1991  AR0600200        Little Rock             NaN
# 7            45       1991  AR0600300  North Little Rock             NaN
# 8            46       1991  AR0600300  North Little Rock             NaN
# 9          3020       1991  AR0600300  North Little Rock             NaN
# 10         3021       1991  AR0600300  North Little Rock             NaN
# 11           47       1991  AR0670000             Sevier             NaN
# ...

# %%
df2.head(5)
# Out:
#    INCIDENT_ID  DATA_YEAR        ORI PUB_AGENCY_NAME PUB_AGENCY_UNIT  \
# 0         3015       1991  AR0040200          Rogers             NaN
# 1         3016       1991  AR0290100            Hope             NaN
# 2           43       1991  AR0350100      Pine Bluff             NaN
# 3           44       1991  AR0350100      Pine Bluff             NaN
# 4         3017       1991  AR0350100      Pine Bluff             NaN
#
#   AGENCY_TYPE_NAME STATE_ABBR STATE_NAME       DIVISION_NAME REGION_NAME  ...  \
# 0             City         AR   Arkansas  West South Central       South  ...
# 1             City         AR   Arkansas  West South Central       South  ...
# 2             City         AR   Arkansas  West South Central       South  ...
# 3             City         AR   Arkansas  West South Central       South  ...
# 4             City         AR   Arkansas  West South Central       South  ...
#
#                OFFENDER_RACE OFFENDER_ETHNICITY VICTIM_COUNT  \
# ...

# %%
# filter for 2010 to 2020

# %%
# keep data_year, state_abbr, state_name, region_name, population_group_desc, incident_date, 
# location_name, bias_desc, victim_count, 
# total_individual_victims, offender_race, offense_name, population

# %%
df.OFFENSE_NAME.nunique()
# Out:
# 350

# %%
df.shape
# Out:
# (219073, 28)

# %%
df.describe()
# Out:
#         INCIDENT_ID      DATA_YEAR  ADULT_VICTIM_COUNT  JUVENILE_VICTIM_COUNT  \
# count  2.190730e+05  219073.000000        50907.000000           49035.000000
# mean   2.053502e+05    2005.439269            0.655941               0.085327
# std    3.206649e+05       8.573008            1.241186               0.514365
# min    2.000000e+00    1991.000000            0.000000               0.000000
# 25%    5.477000e+04    1998.000000            0.000000               0.000000
# 50%    1.095380e+05    2005.000000            1.000000               0.000000
# 75%    1.643070e+05    2013.000000            1.000000               0.000000
# max    1.357330e+06    2020.000000          146.000000              60.000000
#
#        TOTAL_OFFENDER_COUNT  ADULT_OFFENDER_COUNT  JUVENILE_OFFENDER_COUNT  \
# count         219073.000000          46841.000000             46834.000000
# mean               0.956330              0.544907                 0.098924
# ...

# %%
df.columns
# Out:
# Index(['INCIDENT_ID', 'DATA_YEAR', 'ORI', 'PUB_AGENCY_NAME', 'PUB_AGENCY_UNIT',
#        'AGENCY_TYPE_NAME', 'STATE_ABBR', 'STATE_NAME', 'DIVISION_NAME',
#        'REGION_NAME', 'POPULATION_GROUP_CODE', 'POPULATION_GROUP_DESC',
#        'INCIDENT_DATE', 'ADULT_VICTIM_COUNT', 'JUVENILE_VICTIM_COUNT',
#        'TOTAL_OFFENDER_COUNT', 'ADULT_OFFENDER_COUNT',
#        'JUVENILE_OFFENDER_COUNT', 'OFFENDER_RACE', 'OFFENDER_ETHNICITY',
#        'VICTIM_COUNT', 'OFFENSE_NAME', 'TOTAL_INDIVIDUAL_VICTIMS',
#        'LOCATION_NAME', 'BIAS_DESC', 'VICTIM_TYPES', 'MULTIPLE_OFFENSE',
#        'MULTIPLE_BIAS'],
#       dtype='object')

# %%
df['LOCATION_NAME'].str.split("/").str[0]
# Out:
# 0           Highway
# 1           Highway
# 2         Residence
# 3           Highway
# 4           Service
#             ...
# 219068         Park
# 219069         Park
# 219070    Residence
# 219071    Residence
# 219072    Residence
# Name: LOCATION_NAME, Length: 219073, dtype: object
